# %%
#import necessary modules for csv files, linear regressions, bayes, and basic plotting
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
from matplotlib import pyplot as plt

# %%
#import csv files for team stats
teams_shooting=pd.read_csv('teams-shooting.csv')
teams_advanced=pd.read_csv('teams-advanced.csv')
teams_averages=pd.read_csv('teams-averages.csv')
teams_per_100=pd.read_csv('teams-per-100-pos.csv')
teams_totals=pd.read_csv('teams-totals.csv')

# %%
#tests to make sure team imports worked correctly
#print(teams_shooting.head(31))
#print(teams_advanced.head(31))
#print(teams_averages.head(31))
#print(teams_per_100.head(31))
#print(teams_totals.head(31))

# %%
#run machine learning regressions on all team stats vs wins
#meant to provide a more in depth look at the regression for individual stats
#section commented out for efficiency, all still works when uncommented
#average stats vs wins.

# %%
#field goals per game vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_averages['FG']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# #print(model.predict(x_test))
# #print(y_test)

# %%
#field goal attempts per game vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_averages['FGA']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#field goal % vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_averages['FG%']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#3 pointers per game vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_averages['3P']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#3 pointers attempted per game vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_averages['3PA']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#3 point percentage per game vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_averages['3P%']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#2 point field goals per game vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_averages['2P']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#2 point field goals attempted per game vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_averages['2PA']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#2 point field goal % per game vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_averages['2P%']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#free throws made per game vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_averages['FT']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#free throw attempts per game vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_averages['FTA']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#free throw % per game vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_averages['FT%']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#offensive rebounds per game vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_averages['ORB']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#defensive rebounds per game vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_averages['DRB']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#total rebounds per game vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_averages['TRB']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#assists per game vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_averages['AST']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#steals per game vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_averages['STL']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#blocks per game vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_averages['BLK']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#turnovers per game vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_averages['TOV']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#personal fouls per game vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_averages['PF']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#points per game vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_averages['PTS']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#per 100 possessions statistics vs wins

# %%
#field goals per 100 possessions vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_per_100['FG']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#field goal attempts per 100 possessions vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_per_100['FGA']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#field goal % per 100 possessions vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_per_100['FG%']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#3 point field goals per 100 possessions vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_per_100['3P']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#3 point field goal attempts per 100 possessions vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_per_100['3PA']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#3 point field goal % per 100 possessions vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_per_100['3P%']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#2 point field goals per 100 possessions vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_per_100['2P']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#2 point field goal attempts per 100 possessions vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_per_100['2PA']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#2 point field goal % per 100 possessions vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_per_100['2P%']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#free throws per 100 possessions vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_per_100['FT']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#free throw attempts per 100 possessions vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_per_100['FTA']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#free throw % per 100 possessions vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_per_100['FT%']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#offensive rebounds per 100 possessions vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_per_100['ORB']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#defensive rebounds per 100 possessions vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_per_100['DRB']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#total rebounds per 100 possessions vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_per_100['TRB']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#assists per 100 possessions vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_per_100['AST']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#steals per 100 possessions vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_per_100['STL']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#blocks per 100 possessions vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_per_100['BLK']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#turnovers per 100 possessions vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_per_100['TOV']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#personal fouls per 100 possessions vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_per_100['PF']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#points per 100 possessions vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_per_100['PTS']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#team totals vs wins
#in theory this section should not differ much at all from the per game section
#it serves more as a data cleaning quality check

# %%
#total field goals vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_totals['FG']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#total field goal attempts vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_totals['FGA']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#field goal % vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_totals['FG%']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#total 3 point field goals vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_totals['3P']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#total 3 point field goal attempts vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_totals['3PA']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#3 point field goal % vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_totals['3P%']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#total 2 point field goals vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_totals['2P']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#total 2 point field goal attempts vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_totals['2PA']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#2 point field goal % vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_totals['2P%']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#total free throws vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_totals['FT']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#total free throw attempts vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_totals['FTA']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#free throw % vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_totals['FT%']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#total offensive rebound vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_totals['ORB']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#total defensive rebounds vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_totals['DRB']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#total all rebounds vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_totals['TRB']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#total assists vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_totals['AST']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#total steals vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_totals['STL']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#total blocks vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_totals['BLK']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#total turnovers vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_totals['TOV']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#total personal fouls vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_totals['PF']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#total points vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_totals['PTS']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#advanced stats vs wins. definitions of each statistic will be included

# %%
#Average age vs. wins. 
#This statistic is self explanatory by its name
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_advanced['Age']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#Pythagorean wins vs. wins. 
#Pythagorean wins are a formula that calculates expected wins and losses based on point scored and points allowed
#very high score is expected
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_advanced['PW']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#pythagorean losses vs wins.
#same definition as above.
#expect approx the same score as above
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_advanced['PL']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#average margin of victory vs wins.
#average marginal score at the end of the game
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_advanced['MOV']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#SOS vs wins.
#SoS stands for strength of schedule, it is a measure of the difficulty of a teams schedule.
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_advanced['SOS']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#SRS vs. wins
#SRS stands for simple rating system. it takes into account margin of victory and strength of schedule as its primary variables
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_advanced['SRS']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#ORTG vs wins.
#ORTG stands for offensive rating. it is an estimate of the average points scored per 100 possessions
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_advanced['ORtg']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#DRtg vs wins
#DRtg stands for defensive rating. it is an estimate of the average points allowed per 100 possessions
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_advanced['DRtg']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#NRtg vs wins.
#NRtg stands for net rating. it is an estimate of a teams average margin of victory
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_advanced['NRtg']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#Pace vs wins.
#pace is an estimate of possessions per 48 minutes
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_advanced['Pace']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#FTR vs wins.
#FTR stands for free throw rate. it is the number of free throw attempts per field goal attempt
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_advanced['FTr']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#3PAR vs wins.
#3PAR stands for 3 point attempt rate. it is the percentage of field goals taken from 3 point range
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_advanced['3PAr']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#TS% vs wins.
#TS% is short for true shooting percentage. it is a measure of shooting efficiency that takes into account the differences between 2 pointers, free throws, and 3 pointers
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_advanced['TS%']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#Offense Four Factors: eFG% vs wins
#eFG% stands for effective field goal %. it adjusts total shooting percentage to include that 3 pointers are more valuable
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_advanced['Offense Four Factors: eFG%']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#Offense Four Factors: TOV% vs wins
#TOV% stands for turnover %. it is an estimate of turnovers committed per 100 plays
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_advanced['Offense Four Factors: TOV%']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#Offense Four Factors: ORB% vs wins
#ORB% stands for offensive rebound %. It is the percentage of available offensive rebounds that the team successfully rebounded
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_advanced['Offense Four Factors: ORB%']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#Offense Four Factors: FT/FGA vs wins
#FT/FGA is the number of free throws per field goal attempt
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_advanced['Offense Four Factors: FT/FGA']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#Defense Four Factors: eFG% vs. wins
#defensive eFG% is the average eFG% allowed to opposing teams
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_advanced['Defense Four Factors: eFG%']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#Defense Four Factors: TOV% vs. wins
#defensive TOV% is the average TOV% for opposing teams
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_advanced['Defense Four Factors: TOV%']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#Defense Four Factors: DRB% vs wins
#DRB% is the percentage of available defensive rebounds that a team grabbed.
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_advanced['Defense Four Factors: DRB%']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#Defense Four Factors: FT/FGA vs. wins
#defensive FT/FGA is free throws allowed per field goal allowed
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_advanced['Defense Four Factors: FT/FGA']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#attendance per game vs wins.
#attendance per is the average number of fans to show up to watch each home game
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_advanced['Attend./G']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#shooting stats vs wins.

# %%
#fg% vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_shooting['FG%']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#average shot distance vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_shooting['Dist.']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
# #2 pointers as a percentage of total shots vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_shooting['2P as % of total shots']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
# #0-3 foot shots as a percentage of total shots vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_shooting['0-3 ft as % of total shots']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#3-10 foot shots as a percentage of total shots vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_shooting['3-10 ft as % of total shots']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
# #10-16 foot shots as a percentage of total shots vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_shooting['10-16 ft as % of total shots']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#16-3P foot shots as a percentage of total shots vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_shooting['16-3P ft as % of total shots']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#3 point shots as a percentage of total shots vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_shooting['3P as % of total shots']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#2P field goal % vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_shooting['2P FG%']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#0-3 ft field goal % vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_shooting['0-3 ft FG%']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#3-10 ft field goal % vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_shooting['3-10 ft FG%']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#10-16 ft field goal % vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_shooting['10-16 ft FG%']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#16ft-3P field goal % vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_shooting['16 ft-3P FG%']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#3P field goal % vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_shooting['3P%']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#% of 2 pointers assisted vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_shooting['% of 2P Astd']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#% of 3 pointers assisted vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_shooting['% of 3P Astd']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#dunk shooting % vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_shooting['Dunk shooting %']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#dunks made vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_shooting['Dunks Made']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#% of shots as layups vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_shooting['% of shots as layups']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#layups made vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_shooting['Layups made']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#corner 3s as a % of total shots vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_shooting['Corner 3PA as a % of total shots']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#corner 3% vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_shooting['Corner 3P%']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#Heaves attempted vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_shooting['Heaves Attempted']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state = 1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#Heaves made vs. wins
# y = teams_advanced['W']
# y=pd.array(y)
# y=y.reshape(-1,1)
# x = teams_shooting['Heaves Made']
# x=pd.array(x)
# x=x.reshape(-1,1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state=1)
# model = LinearRegression()
# model.fit(x_train, y_train)
# print(model.score(x_test, y_test))
# print(model.predict(x_test))
# print(y_test)

# %%
#multiple trials setup page
# z=list(range(10))
# print(z)
teams_advanced_columns=['PW', 'PL', 'MOV', 'SOS', 'SRS', 'ORtg',
       'DRtg', 'NRtg', 'Pace', 'FTr', '3PAr', 'TS%',
       'Offense Four Factors: eFG%', 'Offense Four Factors: TOV%',
       'Offense Four Factors: ORB%', 'Offense Four Factors: FT/FGA',
       'Defense Four Factors: eFG%', 'Defense Four Factors: TOV%',
       'Defense Four Factors: DRB%', 'Defense Four Factors: FT/FGA',
       'Attend.', 'Attend./G']
teams_averages_columns = ['G', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P',
       '2PA', '2P%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL',
       'BLK', 'TOV', 'PF', 'PTS']
teams_per_100_columns=['G', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P',
       '2PA', '2P%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL',
       'BLK', 'TOV', 'PF', 'PTS']
teams_shooting_columns=['G', 'MP', 'FG%', 'Dist.', '2P as % of total shots',
       '0-3 ft as % of total shots', '3-10 ft as % of total shots',
       '10-16 ft as % of total shots', '16-3P ft as % of total shots',
       '3P as % of total shots', '2P FG%', '0-3 ft FG%', '3-10 ft FG%',
       '10-16 ft FG%', '16 ft-3P FG%', '3P%', '% of 2P Astd', '% of 3P Astd',
       'Dunk shooting %', 'Dunks Made', '% of shots as layups', 'Layups made',
       'Corner 3PA as a % of total shots', 'Corner 3P%', 'Heaves Attempted',
       'Heaves Made']
teams_totals_columns=['G', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P',
       '2PA', '2P%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL',
       'BLK', 'TOV', 'PF', 'PTS']

# %%
#team averages linear regression vs wins: 1000 trials
for i in teams_averages_columns:
    results_averages=[]
    for a in list(range(1000)):
        y = teams_advanced['W']
        y=pd.array(y)
        y=y.reshape(-1,1)
        x = teams_averages[i]
        x=pd.array(x)
        x=x.reshape(-1,1)
        x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .5)
        model = LinearRegression()
        model.fit(x_train, y_train)
        results_averages.append(model.score(x_test, y_test))
    print(i)
    print('average score from 1000 trials: ' + str(sum(results_averages)/len(results_averages)))
    print()
# Out:
# G
# average score from 1000 trials: -0.18019937294620916
#
# MP
# average score from 1000 trials: -0.26766534836837674
#
# FG
# average score from 1000 trials: 0.004011800062785499
#
# FGA
# average score from 1000 trials: -0.31111667132531184
#
# FG%
# average score from 1000 trials: 0.2078554682557702
#
# 3P
# average score from 1000 trials: -0.17028565905549062
#
# 3PA
# average score from 1000 trials: -0.28622122085030666
#
# 3P%
# average score from 1000 trials: 0.3284934323248018
#
# 2P
# average score from 1000 trials: -0.24226642558653147
#
# 2PA
# average score from 1000 trials: -0.3405815996750923
#
# 2P%
# average score from 1000 trials: -0.050529008350208085
#
# FT
# average score from 1000 trials: -0.27678617606655054
#
# FTA
# average score from 1000 trials: -0.33637106984453674
#
# FT%
# average score from 1000 trials: -0.09932089772289532
#
# ORB
# average score from 1000 trials: -0.32385411093163374
#
# DRB
# average score from 1000 trials: -0.052941712289206945
#
# ...

# %%
#team advanced stats linear regression vs wins: 1000 trials
for i in teams_advanced_columns:
    results_advanced=[]
    for a in list(range(1000)):
        y = teams_advanced['W']
        y=pd.array(y)
        y=y.reshape(-1,1)
        x = teams_advanced[i]
        x=pd.array(x)
        x=x.reshape(-1,1)
        x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .5)
        model = LinearRegression()
        model.fit(x_train, y_train)
        results_advanced.append(model.score(x_test, y_test))
    print(i)
    print('average score from 1000 trials: ' + str(sum(results_advanced)/len(results_advanced)))
    print()
# Out:
# PW
# average score from 1000 trials: 0.8694343247440294
#
# PL
# average score from 1000 trials: 0.8683314301742759
#
# MOV
# average score from 1000 trials: 0.8589590343190279
#
# SOS
# average score from 1000 trials: 0.6689468667854823
#
# SRS
# average score from 1000 trials: 0.8622464841499221
#
# ORtg
# average score from 1000 trials: 0.5280774128329633
#
# DRtg
# average score from 1000 trials: 0.4840334618566434
#
# NRtg
# average score from 1000 trials: 0.8544913425335638
#
# Pace
# average score from 1000 trials: -0.23630491408719886
#
# FTr
# average score from 1000 trials: -0.34838741332272544
#
# 3PAr
# average score from 1000 trials: -0.31939457018516193
#
# TS%
# average score from 1000 trials: 0.2823752028503985
#
# Offense Four Factors: eFG%
# average score from 1000 trials: 0.26831266380246377
#
# Offense Four Factors: TOV%
# average score from 1000 trials: -0.14201978371902213
#
# Offense Four Factors: ORB%
# average score from 1000 trials: -0.21700248953576917
#
# ...

# %%
#teams per 100 possessions linear regression vs wins: 1000 trials
for i in teams_per_100_columns:
    results_per_100=[]
    for a in list(range(1000)):
        y = teams_advanced['W']
        y=pd.array(y)
        y=y.reshape(-1,1)
        x = teams_per_100[i]
        x=pd.array(x)
        x=x.reshape(-1,1)
        x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .5)
        model = LinearRegression()
        model.fit(x_train, y_train)
        results_per_100.append(model.score(x_test, y_test))
    print(i)
    print('average score from 1000 trials: ' + str(sum(results_per_100)/len(results_per_100)))
    print()
# Out:
# G
# average score from 1000 trials: -0.16117465333559253
#
# MP
# average score from 1000 trials: -0.2809649095659193
#
# FG
# average score from 1000 trials: 0.3188058539718451
#
# FGA
# average score from 1000 trials: -0.2720772453525972
#
# FG%
# average score from 1000 trials: 0.22787482225484207
#
# 3P
# average score from 1000 trials: -0.1601663363941045
#
# 3PA
# average score from 1000 trials: -0.3055165768195471
#
# 3P%
# average score from 1000 trials: 0.3345675926912386
#
# 2P
# average score from 1000 trials: -0.18779548081033962
#
# 2PA
# average score from 1000 trials: -0.29041311621526794
#
# 2P%
# average score from 1000 trials: -0.05387790293939338
#
# FT
# average score from 1000 trials: -0.2520109240575701
#
# FTA
# average score from 1000 trials: -0.34353317583109066
#
# FT%
# average score from 1000 trials: -0.10208408565235053
#
# ORB
# average score from 1000 trials: -0.3180549894385044
#
# DRB
# average score from 1000 trials: 0.05596012641268223
#
# TRB
# ...

# %%
#teams shooting linear regression vs wins: 1000 trials
for i in teams_shooting_columns:
    results_shooting=[]
    for a in list(range(1000)):
        y = teams_advanced['W']
        y=pd.array(y)
        y=y.reshape(-1,1)
        x = teams_shooting[i]
        x=pd.array(x)
        x=x.reshape(-1,1)
        x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .5)
        model = LinearRegression()
        model.fit(x_train, y_train)
        results_shooting.append(model.score(x_test, y_test))
    print(i)
    print('average score from 1000 trials: ' + str(sum(results_shooting)/len(results_shooting)))
    print()
# Out:
# G
# average score from 1000 trials: -0.1448610945563653
#
# MP
# average score from 1000 trials: -0.28023061302131036
#
# FG%
# average score from 1000 trials: 0.22221803819928163
#
# Dist.
# average score from 1000 trials: -0.2494535080464327
#
# 2P as % of total shots
# average score from 1000 trials: -0.32940109684787977
#
# 0-3 ft as % of total shots
# average score from 1000 trials: -0.14105098667345897
#
# 3-10 ft as % of total shots
# average score from 1000 trials: -0.30242677347327346
#
# 10-16 ft as % of total shots
# average score from 1000 trials: -0.08201929793958332
#
# 16-3P ft as % of total shots
# average score from 1000 trials: -0.28242820186906403
#
# 3P as % of total shots
# average score from 1000 trials: -0.31197979040830076
#
# 2P FG%
# average score from 1000 trials: -0.06380856190968197
#
# 0-3 ft FG%
# average score from 1000 trials: 0.045298608325746066
#
# 3-10 ft FG%
# average score from 1000 trials: -0.11662816705771166
#
# 10-16 ft FG%
# ...

# %%
#teams totals linear regression vs wins: 1000 trials
for i in teams_totals_columns:
    results_totals=[]
    for a in list(range(1000)):
        y = teams_advanced['W']
        y=pd.array(y)
        y=y.reshape(-1,1)
        x = teams_totals[i]
        x=pd.array(x)
        x=x.reshape(-1,1)
        x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .5)
        model = LinearRegression()
        model.fit(x_train, y_train)
        results_totals.append(model.score(x_test, y_test))
    print(i)
    print('average score from 1000 trials: ' + str(sum(results_totals)/len(results_totals)))
    print()
# Out:
# G
# average score from 1000 trials: -0.15085037779790353
#
# MP
# average score from 1000 trials: -0.26049365700034943
#
# FG
# average score from 1000 trials: 0.01636842621917814
#
# FGA
# average score from 1000 trials: -0.3296004878188168
#
# FG%
# average score from 1000 trials: 0.23091430120745773
#
# 3P
# average score from 1000 trials: -0.16664773597273294
#
# 3PA
# average score from 1000 trials: -0.2922560172150938
#
# 3P%
# average score from 1000 trials: 0.33269607583658317
#
# 2P
# average score from 1000 trials: -0.2758399599691485
#
# 2PA
# average score from 1000 trials: -0.3489925814996481
#
# 2P%
# average score from 1000 trials: -0.041672810781410274
#
# FT
# average score from 1000 trials: -0.26095825031966957
#
# FTA
# average score from 1000 trials: -0.3375557390574145
#
# FT%
# average score from 1000 trials: -0.09289764309093344
#
# ORB
# average score from 1000 trials: -0.34812561769646727
#
# DRB
# average score from 1000 trials: -0.07862825925945519
#
# TRB
# ...

# %%
#team averages linear regression vs 3P%: 1000 trials
for i in teams_averages_columns:
    results_averages=[]
    for a in list(range(1000)):
        y = teams_shooting['3P%']
        y=pd.array(y)
        y=y.reshape(-1,1)
        x = teams_averages[i]
        x=pd.array(x)
        x=x.reshape(-1,1)
        x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .5)
        model = LinearRegression()
        model.fit(x_train, y_train)
        results_averages.append(model.score(x_test, y_test))
    print(i)
    print('average score from 1000 trials: ' + str(sum(results_averages)/len(results_averages)))
    print()
# Out:
# G
# average score from 1000 trials: -0.17020235984841114
#
# MP
# average score from 1000 trials: -0.269426258939454
#
# FG
# average score from 1000 trials: -0.11155636927150889
#
# FGA
# average score from 1000 trials: -0.2670739121166927
#
# FG%
# average score from 1000 trials: 0.1819417803975354
#
# 3P
# average score from 1000 trials: -0.10754083366769926
#
# 3PA
# average score from 1000 trials: -0.25735640426926787
#
# 3P%
# average score from 1000 trials: 1.0
#
# 2P
# average score from 1000 trials: -0.26907897798462277
#
# 2PA
# average score from 1000 trials: -0.25702824114331013
#
# 2P%
# average score from 1000 trials: -0.2158561875883776
#
# FT
# average score from 1000 trials: -0.32025963636837435
#
# FTA
# average score from 1000 trials: -0.3314892948013694
#
# FT%
# average score from 1000 trials: -0.14589930664153805
#
# ORB
# average score from 1000 trials: -0.2639076989745817
#
# DRB
# average score from 1000 trials: -0.18681781008282655
#
# TRB
# ...

# %%
#team advanced linear regression vs 3P%: 1000 trials
for i in teams_advanced_columns:
    results=[]
    for a in list(range(1000)):
        y = teams_shooting['3P%']
        y=pd.array(y)
        y=y.reshape(-1,1)
        x = teams_advanced[i]
        x=pd.array(x)
        x=x.reshape(-1,1)
        x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .5)
        model = LinearRegression()
        model.fit(x_train, y_train)
        results.append(model.score(x_test, y_test))
    print(i)
    print('average score from 1000 trials: ' + str(sum(results)/len(results)))
    print()
# Out:
# PW
# average score from 1000 trials: 0.2716093281412984
#
# PL
# average score from 1000 trials: 0.27005154016076693
#
# MOV
# average score from 1000 trials: 0.25360190990428905
#
# SOS
# average score from 1000 trials: 0.07389462475661125
#
# SRS
# average score from 1000 trials: 0.25326643879992444
#
# ORtg
# average score from 1000 trials: 0.3598443031458283
#
# DRtg
# average score from 1000 trials: -0.08896508775953557
#
# NRtg
# average score from 1000 trials: 0.24588987409996949
#
# Pace
# average score from 1000 trials: -0.24193470802358896
#
# FTr
# average score from 1000 trials: -0.30457874940579366
#
# 3PAr
# average score from 1000 trials: -0.25455863923472305
#
# TS%
# average score from 1000 trials: 0.41658636183217684
#
# Offense Four Factors: eFG%
# average score from 1000 trials: 0.4096095429233618
#
# Offense Four Factors: TOV%
# average score from 1000 trials: -0.2523971921628366
#
# Offense Four Factors: ORB%
# ...

# %%
#team per 100 linear regression vs 3P%: 1000 trials
for i in teams_per_100_columns:
    results=[]
    for a in list(range(1000)):
        y = teams_shooting['3P%']
        y=pd.array(y)
        y=y.reshape(-1,1)
        x = teams_per_100[i]
        x=pd.array(x)
        x=x.reshape(-1,1)
        x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .5)
        model = LinearRegression()
        model.fit(x_train, y_train)
        results.append(model.score(x_test, y_test))
    print(i)
    print('average score from 1000 trials: ' + str(sum(results)/len(results)))
    print()
# Out:
# G
# average score from 1000 trials: -0.17588855604505765
#
# MP
# average score from 1000 trials: -0.2733178197569886
#
# FG
# average score from 1000 trials: -0.002193677503126672
#
# FGA
# average score from 1000 trials: -0.2601937563744371
#
# FG%
# average score from 1000 trials: 0.1788970536416919
#
# 3P
# average score from 1000 trials: -0.059385059083706095
#
# 3PA
# average score from 1000 trials: -0.2766646451749674
#
# 3P%
# average score from 1000 trials: 1.0
#
# 2P
# average score from 1000 trials: -0.3013068843665677
#
# 2PA
# average score from 1000 trials: -0.2427355422912893
#
# 2P%
# average score from 1000 trials: -0.19464660049230098
#
# FT
# average score from 1000 trials: -0.2931347846650726
#
# FTA
# average score from 1000 trials: -0.34913346328273087
#
# FT%
# average score from 1000 trials: -0.14003657368362948
#
# ORB
# average score from 1000 trials: -0.25295427209354987
#
# DRB
# average score from 1000 trials: -0.14577658856408945
#
# TRB
# ...

# %%
#team shooting linear regression vs 3P%: 1000 trials
for i in teams_shooting_columns:
    results=[]
    for a in list(range(1000)):
        y = teams_shooting['3P%']
        y=pd.array(y)
        y=y.reshape(-1,1)
        x = teams_shooting[i]
        x=pd.array(x)
        x=x.reshape(-1,1)
        x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .5)
        model = LinearRegression()
        model.fit(x_train, y_train)
        results.append(model.score(x_test, y_test))
    print(i)
    print('average score from 1000 trials: ' + str(sum(results)/len(results)))
    print()
# Out:
# G
# average score from 1000 trials: -0.1575289959193531
#
# MP
# average score from 1000 trials: -0.2718466903626133
#
# FG%
# average score from 1000 trials: 0.17949797188050015
#
# Dist.
# average score from 1000 trials: -0.20085146084703082
#
# 2P as % of total shots
# average score from 1000 trials: -0.2620837140268599
#
# 0-3 ft as % of total shots
# average score from 1000 trials: -0.2714874328167513
#
# 3-10 ft as % of total shots
# average score from 1000 trials: -0.011428544627549967
#
# 10-16 ft as % of total shots
# average score from 1000 trials: -0.12193337873137142
#
# 16-3P ft as % of total shots
# average score from 1000 trials: -0.238876436101672
#
# 3P as % of total shots
# average score from 1000 trials: -0.25569704920710196
#
# 2P FG%
# average score from 1000 trials: -0.17876638679126924
#
# 0-3 ft FG%
# average score from 1000 trials: -0.2077862042982483
#
# 3-10 ft FG%
# average score from 1000 trials: -0.2295298778160403
#
# 10-16 ft FG%
# ...

# %%
#team totals linear regression vs 3P%: 1000 trials
for i in teams_totals_columns:
    results=[]
    for a in list(range(1000)):
        y = teams_shooting['3P%']
        y=pd.array(y)
        y=y.reshape(-1,1)
        x = teams_totals[i]
        x=pd.array(x)
        x=x.reshape(-1,1)
        x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .5)
        model = LinearRegression()
        model.fit(x_train, y_train)
        results.append(model.score(x_test, y_test))
    print(i)
    print('average score from 1000 trials: ' + str(sum(results)/len(results)))
    print()
# Out:
# G
# average score from 1000 trials: -0.17708092940735037
#
# MP
# average score from 1000 trials: -0.29818822834479736
#
# FG
# average score from 1000 trials: -0.1266192593600419
#
# FGA
# average score from 1000 trials: -0.2694674850688168
#
# FG%
# average score from 1000 trials: 0.17371172192592052
#
# 3P
# average score from 1000 trials: -0.08618839048405619
#
# 3PA
# average score from 1000 trials: -0.26566292319127305
#
# 3P%
# average score from 1000 trials: 1.0
#
# 2P
# average score from 1000 trials: -0.2790613958694168
#
# 2PA
# average score from 1000 trials: -0.2548712907419307
#
# 2P%
# average score from 1000 trials: -0.20458068052253683
#
# FT
# average score from 1000 trials: -0.29735412747503626
#
# FTA
# average score from 1000 trials: -0.3292357615852113
#
# FT%
# average score from 1000 trials: -0.17314884887831083
#
# ORB
# average score from 1000 trials: -0.2639480761497633
#
# DRB
# average score from 1000 trials: -0.18098460414798137
#
# TRB
# ...

# %%
#team averages linear regression vs pts per 100 possessions: 1000 trials
for i in teams_averages_columns:
    results=[]
    for a in list(range(1000)):
        y = teams_per_100['PTS']
        y=pd.array(y)
        y=y.reshape(-1,1)
        x = teams_averages[i]
        x=pd.array(x)
        x=x.reshape(-1,1)
        x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .5)
        model = LinearRegression()
        model.fit(x_train, y_train)
        results.append(model.score(x_test, y_test))
    print(i)
    print('average score from 1000 trials: ' + str(sum(results)/len(results)))
    print()
# Out:
# G
# average score from 1000 trials: -0.17507167805083518
#
# MP
# average score from 1000 trials: -0.30856056184239994
#
# FG
# average score from 1000 trials: 0.2538000910996946
#
# FGA
# average score from 1000 trials: -0.30782054223148503
#
# FG%
# average score from 1000 trials: 0.41209064396496176
#
# 3P
# average score from 1000 trials: -0.20744711391013773
#
# 3PA
# average score from 1000 trials: -0.3083641726537036
#
# 3P%
# average score from 1000 trials: 0.2632271762129096
#
# 2P
# average score from 1000 trials: -0.15889346367920118
#
# 2PA
# average score from 1000 trials: -0.31757126667842045
#
# 2P%
# average score from 1000 trials: 0.12363108974278002
#
# FT
# average score from 1000 trials: -0.19606567192889934
#
# FTA
# average score from 1000 trials: -0.38246055467881396
#
# FT%
# average score from 1000 trials: -0.17323485475522532
#
# ORB
# average score from 1000 trials: -0.2607584300175094
#
# DRB
# average score from 1000 trials: -0.2742860855028833
#
# TRB
# ...

# %%
#team advanced linear regression vs pts per 100 possessions: 1000 trials
for i in teams_advanced_columns:
    results=[]
    for a in list(range(1000)):
        y = teams_per_100['PTS']
        y=pd.array(y)
        y=y.reshape(-1,1)
        x = teams_advanced[i]
        x=pd.array(x)
        x=x.reshape(-1,1)
        x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .5)
        model = LinearRegression()
        model.fit(x_train, y_train)
        results.append(model.score(x_test, y_test))
    print(i)
    print('average score from 1000 trials: ' + str(sum(results)/len(results)))
    print()
# Out:
# PW
# average score from 1000 trials: 0.6159981664285288
#
# PL
# average score from 1000 trials: 0.610641605927305
#
# MOV
# average score from 1000 trials: 0.6131107548815881
#
# SOS
# average score from 1000 trials: 0.3789066146714587
#
# SRS
# average score from 1000 trials: 0.608321778477243
#
# ORtg
# average score from 1000 trials: 1.0
#
# DRtg
# average score from 1000 trials: -0.08211376809223271
#
# NRtg
# average score from 1000 trials: 0.6126960784826562
#
# Pace
# average score from 1000 trials: -0.2488324998753742
#
# FTr
# average score from 1000 trials: -0.36817786691170246
#
# 3PAr
# average score from 1000 trials: -0.31397801484674576
#
# TS%
# average score from 1000 trials: 0.47024173229760374
#
# Offense Four Factors: eFG%
# average score from 1000 trials: 0.45011674995705736
#
# Offense Four Factors: TOV%
# average score from 1000 trials: -0.07985346382227049
#
# Offense Four Factors: ORB%
# average score from 1000 trials: -0.2044623511656829
#
# ...

# %%
#team per 100 possessions linear regression vs pts per 100 possessions: 1000 trials
for i in teams_per_100_columns:
    results=[]
    for a in list(range(1000)):
        y = teams_per_100['PTS']
        y=pd.array(y)
        y=y.reshape(-1,1)
        x = teams_per_100[i]
        x=pd.array(x)
        x=x.reshape(-1,1)
        x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .5)
        model = LinearRegression()
        model.fit(x_train, y_train)
        results.append(model.score(x_test, y_test))
    print(i)
    print('average score from 1000 trials: ' + str(sum(results)/len(results)))
    print()
# Out:
# G
# average score from 1000 trials: -0.17694716772447075
#
# MP
# average score from 1000 trials: -0.3263717879206732
#
# FG
# average score from 1000 trials: 0.56803575792259
#
# FGA
# average score from 1000 trials: -0.19289294699481072
#
# FG%
# average score from 1000 trials: 0.41017114087785556
#
# 3P
# average score from 1000 trials: -0.2101956147573762
#
# 3PA
# average score from 1000 trials: -0.3150743982152393
#
# 3P%
# average score from 1000 trials: 0.25376189910250074
#
# 2P
# average score from 1000 trials: -0.11956887772425738
#
# 2PA
# average score from 1000 trials: -0.3179251241994637
#
# 2P%
# average score from 1000 trials: 0.12640689587135015
#
# FT
# average score from 1000 trials: -0.2358607682809636
#
# FTA
# average score from 1000 trials: -0.3629772112874023
#
# FT%
# average score from 1000 trials: -0.16975213039467058
#
# ORB
# average score from 1000 trials: -0.2490886503215265
#
# DRB
# average score from 1000 trials: -0.19890802212680633
#
# TRB
# ...

# %%
#team shooting linear regression vs pts per 100 possessions: 1000 trials
for i in teams_shooting_columns:
    results=[]
    for a in list(range(1000)):
        y = teams_per_100['PTS']
        y=pd.array(y)
        y=y.reshape(-1,1)
        x = teams_shooting[i]
        x=pd.array(x)
        x=x.reshape(-1,1)
        x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .5)
        model = LinearRegression()
        model.fit(x_train, y_train)
        results.append(model.score(x_test, y_test))
    print(i)
    print('average score from 1000 trials: ' + str(sum(results)/len(results)))
    print()
# Out:
# G
# average score from 1000 trials: -0.180800131088135
#
# MP
# average score from 1000 trials: -0.29795733761609167
#
# FG%
# average score from 1000 trials: 0.4181021252389253
#
# Dist.
# average score from 1000 trials: -0.2819614272779971
#
# 2P as % of total shots
# average score from 1000 trials: -0.3277497495563036
#
# 0-3 ft as % of total shots
# average score from 1000 trials: -0.34800119627952564
#
# 3-10 ft as % of total shots
# average score from 1000 trials: -0.35093827300142516
#
# 10-16 ft as % of total shots
# average score from 1000 trials: -0.18420100168016917
#
# 16-3P ft as % of total shots
# average score from 1000 trials: -0.4130831996247023
#
# 3P as % of total shots
# average score from 1000 trials: -0.31874629674090954
#
# 2P FG%
# average score from 1000 trials: 0.07252548688702172
#
# 0-3 ft FG%
# average score from 1000 trials: -0.03345989896467487
#
# 3-10 ft FG%
# average score from 1000 trials: -0.1862936687594195
#
# 10-16 ft FG%
# ...

# %%
#team totals linear regression vs pts per 100 possessions: 1000 trials
for i in teams_totals_columns:
    results=[]
    for a in list(range(1000)):
        y = teams_per_100['PTS']
        y=pd.array(y)
        y=y.reshape(-1,1)
        x = teams_totals[i]
        x=pd.array(x)
        x=x.reshape(-1,1)
        x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .5)
        model = LinearRegression()
        model.fit(x_train, y_train)
        results.append(model.score(x_test, y_test))
    print(i)
    print('average score from 1000 trials: ' + str(sum(results)/len(results)))
    print()
# Out:
# G
# average score from 1000 trials: -0.18273479810760482
#
# MP
# average score from 1000 trials: -0.31825782862312896
#
# FG
# average score from 1000 trials: 0.2067548043214837
#
# FGA
# average score from 1000 trials: -0.2792372633680083
#
# FG%
# average score from 1000 trials: 0.40965263426084675
#
# 3P
# average score from 1000 trials: -0.22347892474100986
#
# 3PA
# average score from 1000 trials: -0.3295572542393855
#
# 3P%
# average score from 1000 trials: 0.27758266192148695
#
# 2P
# average score from 1000 trials: -0.14469781755611869
#
# 2PA
# average score from 1000 trials: -0.3193018924496732
#
# 2P%
# average score from 1000 trials: 0.14064272279068815
#
# FT
# average score from 1000 trials: -0.21781508503351618
#
# FTA
# average score from 1000 trials: -0.3463492261494276
#
# FT%
# average score from 1000 trials: -0.1483167322962786
#
# ORB
# average score from 1000 trials: -0.2636927133893208
#
# DRB
# average score from 1000 trials: -0.2654541548381975
#
# TRB
# ...

# %%
#teams averages linear regression vs FG per 100 possessions: 1000 trials
for i in teams_averages_columns:
    results=[]
    for a in list(range(1000)):
        y = teams_per_100['FG']
        y=pd.array(y)
        y=y.reshape(-1,1)
        x = teams_averages[i]
        x=pd.array(x)
        x=x.reshape(-1,1)
        x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .5)
        model = LinearRegression()
        model.fit(x_train, y_train)
        results.append(model.score(x_test, y_test))
    print(i)
    print('average score from 1000 trials: ' + str(sum(results)/len(results)))
    print()
# Out:
# G
# average score from 1000 trials: -0.17962597315971315
#
# MP
# average score from 1000 trials: -0.2579104917982835
#
# FG
# average score from 1000 trials: 0.7627946046700055
#
# FGA
# average score from 1000 trials: -0.09214808535029934
#
# FG%
# average score from 1000 trials: 0.5541341848861364
#
# 3P
# average score from 1000 trials: -0.27017171662783634
#
# 3PA
# average score from 1000 trials: -0.21213513029317477
#
# 3P%
# average score from 1000 trials: 0.048750095362193165
#
# 2P
# average score from 1000 trials: 0.45681303339272983
#
# 2PA
# average score from 1000 trials: 0.014204389032655388
#
# 2P%
# average score from 1000 trials: 0.005734991188681202
#
# FT
# average score from 1000 trials: -0.3198005228995558
#
# FTA
# average score from 1000 trials: -0.3575283009036069
#
# FT%
# average score from 1000 trials: -0.2611118998377757
#
# ORB
# average score from 1000 trials: -0.234206100839585
#
# DRB
# average score from 1000 trials: -0.25517584731298687
#
# TRB
# ...

# %%
#teams advanced linear regression vs FG per 100 possessions: 1000 trials
for i in teams_advanced_columns:
    results=[]
    for a in list(range(1000)):
        y = teams_per_100['FG']
        y=pd.array(y)
        y=y.reshape(-1,1)
        x = teams_advanced[i]
        x=pd.array(x)
        x=x.reshape(-1,1)
        x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .5)
        model = LinearRegression()
        model.fit(x_train, y_train)
        results.append(model.score(x_test, y_test))
    print(i)
    print('average score from 1000 trials: ' + str(sum(results)/len(results)))
    print()
# Out:
# PW
# average score from 1000 trials: 0.33672470323235565
#
# PL
# average score from 1000 trials: 0.33141645657605706
#
# MOV
# average score from 1000 trials: 0.3698056114037608
#
# SOS
# average score from 1000 trials: 0.3029600646552799
#
# SRS
# average score from 1000 trials: 0.3574613658497063
#
# ORtg
# average score from 1000 trials: 0.6210953131073977
#
# DRtg
# average score from 1000 trials: -0.1804073623749937
#
# NRtg
# average score from 1000 trials: 0.365292135760525
#
# Pace
# average score from 1000 trials: -0.2825444172750638
#
# FTr
# average score from 1000 trials: -0.2811164497317829
#
# 3PAr
# average score from 1000 trials: -0.043330775264564476
#
# TS%
# average score from 1000 trials: 0.1076003292511566
#
# Offense Four Factors: eFG%
# average score from 1000 trials: 0.20649908306518114
#
# Offense Four Factors: TOV%
# average score from 1000 trials: 0.07625576452321517
#
# Offense Four Factors: ORB%
# average score from 1000 trials: -0.12697706040949308
#
# ...

# %%
#teams per 100 linear regression vs FG per 100 possessions: 1000 trials
for i in teams_per_100_columns:
    results=[]
    for a in list(range(1000)):
        y = teams_per_100['FG']
        y=pd.array(y)
        y=y.reshape(-1,1)
        x = teams_per_100[i]
        x=pd.array(x)
        x=x.reshape(-1,1)
        x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .5)
        model = LinearRegression()
        model.fit(x_train, y_train)
        results.append(model.score(x_test, y_test))
    print(i)
    print('average score from 1000 trials: ' + str(sum(results)/len(results)))
    print()
# Out:
# G
# average score from 1000 trials: -0.17422937585428416
#
# MP
# average score from 1000 trials: -0.27278284422867727
#
# FG
# average score from 1000 trials: 1.0
#
# FGA
# average score from 1000 trials: -0.02463471773862421
#
# FG%
# average score from 1000 trials: 0.5515031050611812
#
# 3P
# average score from 1000 trials: -0.2463529048831733
#
# 3PA
# average score from 1000 trials: -0.15429406906044302
#
# 3P%
# average score from 1000 trials: 0.02213701484290022
#
# 2P
# average score from 1000 trials: 0.4860243754884991
#
# 2PA
# average score from 1000 trials: 0.01687259558480287
#
# 2P%
# average score from 1000 trials: 0.021096020982713872
#
# FT
# average score from 1000 trials: -0.34306446152182396
#
# FTA
# average score from 1000 trials: -0.36066450011539064
#
# FT%
# average score from 1000 trials: -0.2370036207341666
#
# ORB
# average score from 1000 trials: -0.26684496956810916
#
# DRB
# average score from 1000 trials: -0.2828543535475225
#
# TRB
# ...

# %%
#teams shooting linear regression vs FG per 100 possessions: 1000 trials
for i in teams_shooting_columns:
    results=[]
    for a in list(range(1000)):
        y = teams_per_100['FG']
        y=pd.array(y)
        y=y.reshape(-1,1)
        x = teams_shooting[i]
        x=pd.array(x)
        x=x.reshape(-1,1)
        x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .5)
        model = LinearRegression()
        model.fit(x_train, y_train)
        results.append(model.score(x_test, y_test))
    print(i)
    print('average score from 1000 trials: ' + str(sum(results)/len(results)))
    print()
# Out:
# G
# average score from 1000 trials: -0.16575377322610027
#
# MP
# average score from 1000 trials: -0.2624496109468663
#
# FG%
# average score from 1000 trials: 0.5626762057201744
#
# Dist.
# average score from 1000 trials: -0.18919044110415367
#
# 2P as % of total shots
# average score from 1000 trials: -0.07356997478475547
#
# 0-3 ft as % of total shots
# average score from 1000 trials: -0.3462690014314582
#
# 3-10 ft as % of total shots
# average score from 1000 trials: -0.39061324230181355
#
# 10-16 ft as % of total shots
# average score from 1000 trials: 0.10715671689405469
#
# 16-3P ft as % of total shots
# average score from 1000 trials: -0.2283290572646548
#
# 3P as % of total shots
# average score from 1000 trials: -0.05932007820458893
#
# 2P FG%
# average score from 1000 trials: 0.02044883722233402
#
# 0-3 ft FG%
# average score from 1000 trials: -0.10371591065990074
#
# 3-10 ft FG%
# average score from 1000 trials: -0.055188103672517946
#
# 10-16 ft FG%
# ...

# %%
#teams totals linear regression vs FG per 100 possessions: 1000 trials
for i in teams_totals_columns:
    results=[]
    for a in list(range(1000)):
        y = teams_per_100['FG']
        y=pd.array(y)
        y=y.reshape(-1,1)
        x = teams_totals[i]
        x=pd.array(x)
        x=x.reshape(-1,1)
        x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .5)
        model = LinearRegression()
        model.fit(x_train, y_train)
        results.append(model.score(x_test, y_test))
    print(i)
    print('average score from 1000 trials: ' + str(sum(results)/len(results)))
    print()
# Out:
# G
# average score from 1000 trials: -0.17282938873048012
#
# MP
# average score from 1000 trials: -0.2539086970895388
#
# FG
# average score from 1000 trials: 0.7610497479795468
#
# FGA
# average score from 1000 trials: -0.09504791995916544
#
# FG%
# average score from 1000 trials: 0.5508006960791632
#
# 3P
# average score from 1000 trials: -0.25552968879716653
#
# 3PA
# average score from 1000 trials: -0.15430668830436384
#
# 3P%
# average score from 1000 trials: 0.03449672424842253
#
# 2P
# average score from 1000 trials: 0.45730264272142335
#
# 2PA
# average score from 1000 trials: 0.010807702627270054
#
# 2P%
# average score from 1000 trials: 0.03682453406740238
#
# FT
# average score from 1000 trials: -0.3526484267070496
#
# FTA
# average score from 1000 trials: -0.38086253415942684
#
# FT%
# average score from 1000 trials: -0.25831467981546297
#
# ORB
# average score from 1000 trials: -0.27585554020167297
#
# DRB
# average score from 1000 trials: -0.25467067872799115
#
# TRB
# ...

# %%
#teams averages linear regression vs MOV: 1000 trials
for i in teams_averages_columns:
    results=[]
    for a in list(range(1000)):
        y = teams_advanced['MOV']
        y=pd.array(y)
        y=y.reshape(-1,1)
        x = teams_averages[i]
        x=pd.array(x)
        x=x.reshape(-1,1)
        x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .5)
        model = LinearRegression()
        model.fit(x_train, y_train)
        results.append(model.score(x_test, y_test))
    print(i)
    print('average score from 1000 trials: ' + str(sum(results)/len(results)))
    print()
# Out:
# G
# average score from 1000 trials: -0.16451191208487975
#
# MP
# average score from 1000 trials: -0.30989281812530417
#
# FG
# average score from 1000 trials: 0.05239774454032597
#
# FGA
# average score from 1000 trials: -0.28571198937623915
#
# FG%
# average score from 1000 trials: 0.17660580996187225
#
# 3P
# average score from 1000 trials: -0.13655258764792155
#
# 3PA
# average score from 1000 trials: -0.31041724934117915
#
# 3P%
# average score from 1000 trials: 0.2772404118430097
#
# 2P
# average score from 1000 trials: -0.2660775784156443
#
# 2PA
# average score from 1000 trials: -0.322213119206124
#
# 2P%
# average score from 1000 trials: -0.014176267764137301
#
# FT
# average score from 1000 trials: -0.26632626249099717
#
# FTA
# average score from 1000 trials: -0.3331773054829196
#
# FT%
# average score from 1000 trials: -0.1765779231796347
#
# ORB
# average score from 1000 trials: -0.24727959572308866
#
# DRB
# average score from 1000 trials: -0.054703907132647944
#
# TRB
# ...

# %%
#teams advanced linear regression vs MOV: 1000 trials
for i in teams_advanced_columns:
    results=[]
    for a in list(range(1000)):
        y = teams_advanced['MOV']
        y=pd.array(y)
        y=y.reshape(-1,1)
        x = teams_advanced[i]
        x=pd.array(x)
        x=x.reshape(-1,1)
        x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .5)
        model = LinearRegression()
        model.fit(x_train, y_train)
        results.append(model.score(x_test, y_test))
    print(i)
    print('average score from 1000 trials: ' + str(sum(results)/len(results)))
    print()
# Out:
# PW
# average score from 1000 trials: 0.9979155658159157
#
# PL
# average score from 1000 trials: 0.9979160307521805
#
# MOV
# average score from 1000 trials: 1.0
#
# SOS
# average score from 1000 trials: 0.7098663663978011
#
# SRS
# average score from 1000 trials: 0.9993555349797599
#
# ORtg
# average score from 1000 trials: 0.6413989907691131
#
# DRtg
# average score from 1000 trials: 0.5483837007168729
#
# NRtg
# average score from 1000 trials: 0.9995895479644349
#
# Pace
# average score from 1000 trials: -0.21556153156162944
#
# FTr
# average score from 1000 trials: -0.35611178424128703
#
# 3PAr
# average score from 1000 trials: -0.2927373754243097
#
# TS%
# average score from 1000 trials: 0.2733098397670683
#
# Offense Four Factors: eFG%
# average score from 1000 trials: 0.2802530000806338
#
# Offense Four Factors: TOV%
# average score from 1000 trials: -0.158340348068004
#
# Offense Four Factors: ORB%
# average score from 1000 trials: -0.11633493476101797
#
# ...

# %%
#teams per 100 linear regression vs MOV: 1000 trials
for i in teams_per_100_columns:
    results=[]
    for a in list(range(1000)):
        y = teams_advanced['MOV']
        y=pd.array(y)
        y=y.reshape(-1,1)
        x = teams_per_100[i]
        x=pd.array(x)
        x=x.reshape(-1,1)
        x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .5)
        model = LinearRegression()
        model.fit(x_train, y_train)
        results.append(model.score(x_test, y_test))
    print(i)
    print('average score from 1000 trials: ' + str(sum(results)/len(results)))
    print()
# Out:
# G
# average score from 1000 trials: -0.1618423279269429
#
# MP
# average score from 1000 trials: -0.2949929092147486
#
# FG
# average score from 1000 trials: 0.3669526765459686
#
# FGA
# average score from 1000 trials: -0.17947794527439007
#
# FG%
# average score from 1000 trials: 0.18974419124588013
#
# 3P
# average score from 1000 trials: -0.09191466402670151
#
# 3PA
# average score from 1000 trials: -0.29039895873397314
#
# 3P%
# average score from 1000 trials: 0.2815090591696668
#
# 2P
# average score from 1000 trials: -0.1844892592924125
#
# 2PA
# average score from 1000 trials: -0.33554422123970007
#
# 2P%
# average score from 1000 trials: -0.029621484873859228
#
# FT
# average score from 1000 trials: -0.23053214911443917
#
# FTA
# average score from 1000 trials: -0.33964586564656374
#
# FT%
# average score from 1000 trials: -0.14171633340989243
#
# ORB
# average score from 1000 trials: -0.212602853232726
#
# DRB
# average score from 1000 trials: 0.09429320318614819
#
# TRB
# ...

# %%
#teams shooting linear regression vs MOV: 1000 trials
for i in teams_shooting_columns:
    results=[]
    for a in list(range(1000)):
        y = teams_advanced['MOV']
        y=pd.array(y)
        y=y.reshape(-1,1)
        x = teams_shooting[i]
        x=pd.array(x)
        x=x.reshape(-1,1) 
        x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .5)
        model = LinearRegression()
        model.fit(x_train, y_train)
        results.append(model.score(x_test, y_test))
    print(i)
    print('average score from 1000 trials: ' + str(sum(results)/len(results)))
    print()
# Out:
# G
# average score from 1000 trials: -0.197383529835581
#
# MP
# average score from 1000 trials: -0.3095246307489816
#
# FG%
# average score from 1000 trials: 0.19179012340143448
#
# Dist.
# average score from 1000 trials: -0.2384896371224385
#
# 2P as % of total shots
# average score from 1000 trials: -0.3212168306079681
#
# 0-3 ft as % of total shots
# average score from 1000 trials: -0.17029705920409444
#
# 3-10 ft as % of total shots
# average score from 1000 trials: -0.33468581460886265
#
# 10-16 ft as % of total shots
# average score from 1000 trials: -0.15086346929182853
#
# 16-3P ft as % of total shots
# average score from 1000 trials: -0.2991691494042489
#
# 3P as % of total shots
# average score from 1000 trials: -0.3171692484435228
#
# 2P FG%
# average score from 1000 trials: -0.015734186322949775
#
# 0-3 ft FG%
# average score from 1000 trials: 0.06324306016718682
#
# 3-10 ft FG%
# average score from 1000 trials: -0.09447506363555712
#
# 10-16 ft FG%
# ...

# %%
#teams totals linear regression vs MOV: 1000 trials
for i in teams_totals_columns:
    results=[]
    for a in list(range(1000)):
        y = teams_advanced['MOV']
        y=pd.array(y)
        y=y.reshape(-1,1)
        x = teams_totals[i]
        x=pd.array(x)
        x=x.reshape(-1,1)
        x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .5)
        model = LinearRegression()
        model.fit(x_train, y_train)
        results.append(model.score(x_test, y_test))
    print(i)
    print('average score from 1000 trials: ' + str(sum(results)/len(results)))
    print()
# Out:
# G
# average score from 1000 trials: -0.16495687327870617
#
# MP
# average score from 1000 trials: -0.3423121044331964
#
# FG
# average score from 1000 trials: 0.020268822297740394
#
# FGA
# average score from 1000 trials: -0.30248514092985346
#
# FG%
# average score from 1000 trials: 0.18744233515309286
#
# 3P
# average score from 1000 trials: -0.14626974566779036
#
# 3PA
# average score from 1000 trials: -0.31056515668168566
#
# 3P%
# average score from 1000 trials: 0.28330703385789735
#
# 2P
# average score from 1000 trials: -0.2571134578186916
#
# 2PA
# average score from 1000 trials: -0.36711401124513227
#
# 2P%
# average score from 1000 trials: -0.02652593781196242
#
# FT
# average score from 1000 trials: -0.26674784952253305
#
# FTA
# average score from 1000 trials: -0.3452669560394339
#
# FT%
# average score from 1000 trials: -0.1571480302713096
#
# ORB
# average score from 1000 trials: -0.21714637896867348
#
# DRB
# average score from 1000 trials: -0.03200886918884926
#
# ...

# %%
#teams averages linear regression vs NRtg: 1000 trials
for i in teams_averages_columns:
    results=[]
    for a in list(range(1000)):
        y = teams_advanced['NRtg']
        y=pd.array(y)
        y=y.reshape(-1,1)
        x = teams_averages[i]
        x=pd.array(x)
        x=x.reshape(-1,1)
        x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .5)
        model = LinearRegression()
        model.fit(x_train, y_train)
        results.append(model.score(x_test, y_test))
    print(i)
    print('average score from 1000 trials: ' + str(sum(results)/len(results)))
    print()
# Out:
# G
# average score from 1000 trials: -0.15337093260230067
#
# MP
# average score from 1000 trials: -0.31613168612117787
#
# FG
# average score from 1000 trials: 0.02837557340820583
#
# FGA
# average score from 1000 trials: -0.30845966302541145
#
# FG%
# average score from 1000 trials: 0.19844094905880874
#
# 3P
# average score from 1000 trials: -0.14496624299227112
#
# 3PA
# average score from 1000 trials: -0.2993957105549646
#
# 3P%
# average score from 1000 trials: 0.29252766069427927
#
# 2P
# average score from 1000 trials: -0.22581324771844793
#
# 2PA
# average score from 1000 trials: -0.3604883837933158
#
# 2P%
# average score from 1000 trials: -0.008224931613996619
#
# FT
# average score from 1000 trials: -0.25751090073625665
#
# FTA
# average score from 1000 trials: -0.3305807483431848
#
# FT%
# average score from 1000 trials: -0.15165862078190287
#
# ORB
# average score from 1000 trials: -0.24453051279875243
#
# DRB
# average score from 1000 trials: -0.0385148215303172
#
# ...

# %%
#teams advanced linear regression vs NRtg: 1000 trials
for i in teams_advanced_columns:
    results=[]
    for a in list(range(1000)):
        y = teams_advanced['NRtg']
        y=pd.array(y)
        y=y.reshape(-1,1)
        x = teams_advanced[i]
        x=pd.array(x)
        x=x.reshape(-1,1)
        x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .5)
        model = LinearRegression()
        model.fit(x_train, y_train)
        results.append(model.score(x_test, y_test))
    print(i)
    print('average score from 1000 trials: ' + str(sum(results)/len(results)))
    print()
# Out:
# PW
# average score from 1000 trials: 0.998121081458364
#
# PL
# average score from 1000 trials: 0.9981139504462176
#
# MOV
# average score from 1000 trials: 0.9995945687505745
#
# SOS
# average score from 1000 trials: 0.7033271805001599
#
# SRS
# average score from 1000 trials: 0.9989137493184321
#
# ORtg
# average score from 1000 trials: 0.6376439324822606
#
# DRtg
# average score from 1000 trials: 0.5545922876068564
#
# NRtg
# average score from 1000 trials: 1.0
#
# Pace
# average score from 1000 trials: -0.20603961720298142
#
# FTr
# average score from 1000 trials: -0.35173062091100393
#
# 3PAr
# average score from 1000 trials: -0.3322707867479189
#
# TS%
# average score from 1000 trials: 0.2836183456683029
#
# Offense Four Factors: eFG%
# average score from 1000 trials: 0.30864867384806866
#
# Offense Four Factors: TOV%
# average score from 1000 trials: -0.17975608462676265
#
# Offense Four Factors: ORB%
# average score from 1000 trials: -0.13347043968743558
#
# ...

# %%
#teams per 100 linear regression vs NRtg: 1000 trials
for i in teams_per_100_columns:
    results=[]
    for a in list(range(1000)):
        y = teams_advanced['NRtg']
        y=pd.array(y)
        y=y.reshape(-1,1)
        x = teams_per_100[i]
        x=pd.array(x)
        x=x.reshape(-1,1)
        x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .5)
        model = LinearRegression()
        model.fit(x_train, y_train)
        results.append(model.score(x_test, y_test))
    print(i)
    print('average score from 1000 trials: ' + str(sum(results)/len(results)))
    print()
# Out:
# G
# average score from 1000 trials: -0.1502563329283683
#
# MP
# average score from 1000 trials: -0.2953025556001347
#
# FG
# average score from 1000 trials: 0.36500168005468264
#
# FGA
# average score from 1000 trials: -0.193450247590198
#
# FG%
# average score from 1000 trials: 0.1946488476932458
#
# 3P
# average score from 1000 trials: -0.10565245273110938
#
# 3PA
# average score from 1000 trials: -0.30660405301769267
#
# 3P%
# average score from 1000 trials: 0.2828958228417412
#
# 2P
# average score from 1000 trials: -0.22290378791571236
#
# 2PA
# average score from 1000 trials: -0.3225417495585724
#
# 2P%
# average score from 1000 trials: -0.01386999623072509
#
# FT
# average score from 1000 trials: -0.23698288649005597
#
# FTA
# average score from 1000 trials: -0.32201346027025307
#
# FT%
# average score from 1000 trials: -0.1635239117154633
#
# ORB
# average score from 1000 trials: -0.2131202929579165
#
# DRB
# average score from 1000 trials: 0.11293115826782951
#
# TRB
# ...

# %%
#teams shooting linear regression vs NRtg: 1000 trials
for i in teams_shooting_columns:
    results=[]
    for a in list(range(1000)):
        y = teams_advanced['NRtg']
        y=pd.array(y)
        y=y.reshape(-1,1)
        x = teams_shooting[i]
        x=pd.array(x)
        x=x.reshape(-1,1) 
        x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .5)
        model = LinearRegression()
        model.fit(x_train, y_train)
        results.append(model.score(x_test, y_test))
    print(i)
    print('average score from 1000 trials: ' + str(sum(results)/len(results)))
    print()
# Out:
# G
# average score from 1000 trials: -0.158620825362228
#
# MP
# average score from 1000 trials: -0.32321455549094535
#
# FG%
# average score from 1000 trials: 0.19468647821269802
#
# Dist.
# average score from 1000 trials: -0.25869352418167746
#
# 2P as % of total shots
# average score from 1000 trials: -0.3333267565521889
#
# 0-3 ft as % of total shots
# average score from 1000 trials: -0.17693930318316126
#
# 3-10 ft as % of total shots
# average score from 1000 trials: -0.33499765600182324
#
# 10-16 ft as % of total shots
# average score from 1000 trials: -0.1499256958560966
#
# 16-3P ft as % of total shots
# average score from 1000 trials: -0.3217064068540621
#
# 3P as % of total shots
# average score from 1000 trials: -0.3448983320410759
#
# 2P FG%
# average score from 1000 trials: -0.008671504624420588
#
# 0-3 ft FG%
# average score from 1000 trials: 0.07875549238891794
#
# 3-10 ft FG%
# average score from 1000 trials: -0.0997158635760022
#
# 10-16 ft FG%
# ...

# %%
#teams totals linear regression vs NRtg: 1000 trials
for i in teams_totals_columns:
    results=[]
    for a in list(range(1000)):
        y = teams_advanced['NRtg']
        y=pd.array(y)
        y=y.reshape(-1,1)
        x = teams_totals[i]
        x=pd.array(x)
        x=x.reshape(-1,1)
        x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .5)
        model = LinearRegression()
        model.fit(x_train, y_train)
        results.append(model.score(x_test, y_test))
    print(i)
    print('average score from 1000 trials: ' + str(sum(results)/len(results)))
    print()
# Out:
# G
# average score from 1000 trials: -0.1703589941364698
#
# MP
# average score from 1000 trials: -0.3265476766596927
#
# FG
# average score from 1000 trials: 3.986360613779183e-05
#
# FGA
# average score from 1000 trials: -0.294666578338192
#
# FG%
# average score from 1000 trials: 0.19062258476843483
#
# 3P
# average score from 1000 trials: -0.13782358192946792
#
# 3PA
# average score from 1000 trials: -0.2901919237111508
#
# 3P%
# average score from 1000 trials: 0.2846675138974824
#
# 2P
# average score from 1000 trials: -0.2726330037450158
#
# 2PA
# average score from 1000 trials: -0.32976518614835443
#
# 2P%
# average score from 1000 trials: -0.013671772818657191
#
# FT
# average score from 1000 trials: -0.26209023563391304
#
# FTA
# average score from 1000 trials: -0.3690003608086566
#
# FT%
# average score from 1000 trials: -0.16028356057078408
#
# ORB
# average score from 1000 trials: -0.2403923960488029
#
# DRB
# average score from 1000 trials: -0.034910750816427846
#
# TRB
# ...
